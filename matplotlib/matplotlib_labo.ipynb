# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Topics**
# * matplotlib (quick experimentation)

# %%
x = np.linspace(-2,2,20)
y = -(x+1)**2 +3
plt.plot(x, y, '--k')

# %%
plt.plot(x,-x)
r = np.linspace(0,10,.1)
theta = np.linspace(-np.pi, np.pi, 36, )

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)

# %%
print fig
print ax
# Out:
# Figure(480x320)
# [[<matplotlib.axes.AxesSubplot object at 0x31ebd90>
# ...

# %%
x = np.linspace(0,1,20)
for i in range(1,5):
    plt.plot(x, x**i, str(i)+'-')
ax = plt.gca()
ax.set_xlim([0,1])
line = ax.lines[2]
line.set_marker('o')

# %%
r = np.arange(360)
theta = r / (180/np.pi)
plt.polar(theta, r)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/cbook.py:1508: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   result = np.zeros(new_shape, a.dtype)
# /usr/lib/pymodules/python2.7/matplotlib/cbook.py:1516: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   result[i::steps] = delta * i + a0
# /usr/lib/pymodules/python2.7/matplotlib/cbook.py:1517: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   result[steps::steps] = a1

# %%
import IPython.html.widgets as widgets

# %%
def f(a):
    print(a**2)
widgets.interact(f, a=(-1,1,0.1))
# Out:
# 0.01
# <function __main__.f>

# %%
def coscos(a,b):
    plt.plot(x, np.cos(x), 'k', label='$\cos(x)$')
    plt.plot(x, a*np.cos(x+b), 'r', label='$a*\sin(x+b)$')
    plt.xlim(-2*np.pi, 2*np.pi)
    plt.ylim(-2,2)

x = np.linspace(-2*np.pi, 2*np.pi)

# %%
coscos(1.4,np.pi)

# %%
widgets.interact(coscos, a = (-2,2,0.1), b =(0,2*np.pi,0.1))
# Out:
# <function __main__.coscos>
