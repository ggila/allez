# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-2,2,20)
y = -(x+1)**2 +3
plt.plot(x, y, '--k')

# %%
plt.plot(x,-x)
r = np.linspace(0,10,.1)
theta = np.linspace(-np.pi, np.pi, 36, )

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)

# %%
print fig
print ax
# Out:
# Figure(480x320)
# [[<matplotlib.axes.AxesSubplot object at 0x489a3d0>
#   <matplotlib.axes.AxesSubplot object at 0x4aa7b50>]
#  [<matplotlib.axes.AxesSubplot object at 0x4acc110>
#   <matplotlib.axes.AxesSubplot object at 0x4aabe90>]]

# %%
import IPython.html.widgets as widgets
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
def f(a):
    print(a**2)
widgets.interact(f, a=(-1,1,0.1))
# Out:
# 0.01
# <function __main__.f>

# %%
def coscos(a,b):
    plt.plot(x, np.cos(x), 'k', label='$\cos(x)$')
    plt.plot(x, a*np.cos(x+b), 'r', label='$a*\sin(x+b)$')
    plt.xlim(-2*np.pi, 2*np.pi)
    plt.ylim(-2,2)

x = np.linspace(-2*np.pi, 2*np.pi)

# %%
coscos(1.4,np.pi)

# %%
widgets.interact(coscos, a = (-2,2,0.1), b =(0,2*np.pi,0.1))
